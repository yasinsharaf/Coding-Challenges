# %% [markdown]
# **Module 2**

# %% [markdown]
# Expressions & Variables

# %%
#data types
str1 = "Hello, World!"
int1 = 10
float1 = 1.23

# %%
#data collections
list1 = [1,2,3]
tuple1 = (1,2,3) #immutable list
set1 = {1,1,2,3} #distinct values
dict1 = {"key1": 1, "key2": 2}

print(len(set1))
print(dict1['key1'])
# Out:
# 3
# 1

# %% [markdown]
# Explicit Conversion

# %%
print("Each person needs to pay: " + str(12.00)) #int to string to avoid type mismatch
# Out:
# Each person needs to pay: 12.0

# %% [markdown]
# Functions

# %%
#multiple args with return
def find_total_days(years, months, days):
    my_days = (years*365) + (months*30) + days #convert all into days
    return my_days

total_days = find_total_days(2,5,23)
print(total_days)
# Out:
# 903

# %%
#print result in function
def greeting(name):
    print("Welcome, " + name)

result = greeting("Yasin")
result #cannot pass into print
print(result)
# Out:
# Welcome, Yasin
# None

# %% [markdown]
# Conditionals

# %%
#elif statement in single arg function to translate error codes
def translate_error_code(error_code):
    if error_code == "401 Unauthorized":
        translation = "Server received an unauthenticated request"
    elif error_code == "404 Not Found":
        translation = "Requested web page not found on server"
    elif error_code == "408 Request Timeout":
        translation = "Server request to close unused connection"
    else:
        translation = "Unknown error code"
    return translation

print(translate_error_code("404 Not Found"))
# Out:
# Requested web page not found on server

# %% [markdown]
# **Module 3**

# %% [markdown]
# Loops

# %%
#while loop using other functions
#function 1: get_username() fetches
#function 2: valid_username() validates
username = get_username()
while not valid_username(username):
  print("Invalid Username")
  username = get_username()

# %%
#while loop reusing same variable for multiple loops
x = 1
sum = 0
while x < 10:
    sum += x #0+1+2...+9 = 45
    x += 1 #x+1 (8x repeat)

x = 1 #reset x
product = x #cannot start at 0, or result = 0
while x < 10:
    product *= x #9!
    x += 1 #x+1 (8x repeat)

print(sum, product)
# Out:
# 45 362880

# %%
#while loop: multiplication table n* 1 thru 5 <= 25
def multiplication_table(number):
    multiplier = 1 #do not start @0

    while multiplier <= 5:
        result = number * multiplier
        if  result > 25:
            break #stop @25
        print(str(number) + "x" + str(multiplier) + "=" + str(result))
        multiplier += 1 #increment multiplier

multiplication_table(10)
# Out:
# 10x1=10
# 10x2=20
